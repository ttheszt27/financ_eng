# %% [markdown]
# ## Financial Engineering Final Project:
# # The Losers and Occasional Winners of Short Selling, Can We Spot a Potential Short Squeeze?

# %% [markdown]
# Tóth Eszter, 2025 Budapest

# %% [markdown]
# ## Introduction
#
# Short selling is a financial strategy that allows investors to profit from a decline in the price of a security. By borrowing and selling a stock with the intention of buying it back later at a lower price, short sellers can realize gains in falling markets. Traders use short selling as speculation, and investors or portfolio managers may use it as a hedge against the downside risk of a long position. However, this approach can potentially lead to incredible losses (which can be theoretically unlimited) if the given asset's price rises instead.
#
# This project explores notable historical instances where short selling yielded significant profits, as well as some infamous tales, where it led to catastrophic losses. From the 2008 financial crisis and the Wirecard scandal, where short sellers exposed deep-rooted frauds, to the recent short squeezes in stocks like GameStop (GME), in this study I am going to highlight the volatile and unpredictable nature of choosing to bet against the market.
#
# ## Objective
#
# My goals are to:
# - Summarize key literature and highlight some real-world examples related to short selling.
# - Visualize the indicators of a potential short squeeze.
# - Reflect on the risks, dangers and rare rewards of short positions.

# %% [markdown]
# ## A review of the literature
# ### How to short a stock
# Traders commonly engage in short selling for speculation and hedging. Speculation is the act of taking a financial position in a market with the hope of making a profit from price movements. Speculators try to predict future price changes — whether in stocks, commodities, currencies, etc. — and accept risk to make a return. Hedging is a strategy used to reduce or offset risk. Investors or companies use hedging to protect themselves against price changes that could negatively affect their existing positions or operations. To open a short position, a trader must have a margin account and pay interest on the value of the borrowed shares while the position is open.
#
# A broker locates shares that can be borrowed and returns them at the end of the trade. Opening and closing the trade can be done through regular trading platforms with brokers qualified to perform margin trading. The following steps are usually taken by traders who short-sell:
#
# **1. Opening a margin account**
#
# Before they engage in short selling, traders open a margin account with a broker so that they will be able to borrow shares. Margin accounts require minimum balances, called the maintenance margin, which is used to cover potential losses. The broker charges interest on the borrowed shares while short positions remain open.
#
# **2. Identifying a stock to short**
#
# Next, traders identify stocks that they believe will decline in value by analyzing financial reports, industry trends, technical indicators, or broad market sentiment. This involves speculation based on the expectation that the stock's price will drop, allowing the trader to profit by buying it back later at a lower price.
#
# **3. Locating borrowable shares**
#
# Before the trader can short-sell, the broker must locate shares that can be borrowed. Brokerage firms now handle this process automatically, finding shares from other clients' accounts or even institutional lenders.
#
# **4. Placing the short sale order**
#
# Afterwards, the shares will be available on the brokerage platform, or a list of shares that can be shorted will be made available to the trader. The trader enters a market order or a limit order to short the stock.
#
# **5. Monitoring the position**
#
# After opening the short position, experienced traders actively monitor the market and the stock's performance. Since the trader sold borrowed shares, they're expecting the stock price to decline so that they can repurchase the stock at a lower price. However, if the stock price increases, their losses can grow. In theory, there is no limit to how high a stock price can rise, which makes this even riskier for traders.
#
# **6. Closing the short position**
#
# To close the short position, traders must buy back the borrowed shares and return them to the lender. This is known as covering the short. Ideally, the shares are repurchased at a lower price than what the trader sold them for, allowing the trader to keep the difference as profit, less interest charges and commissions. Closing the short position can be achieved by entering a buy order on the brokerage platform for the same number of shares that were sold short.
#
# **7. Reviewing the trade outcome**
#
# Experienced traders review the outcome of the transaction after the position is closed. Analyzing the trade's success or failure helps the trader refine their strategy for future short-selling opportunities.

# %% [markdown]
# ### The costs of short-selling
# Unlike buying and holding stocks or investments, short selling involves significant costs in addition to the usual trading commissions paid to brokers. Some costs include:
# - Margin Interest
# - Stock Borrowing Costs
# - Dividends and Other Costs (the short seller is responsible for making dividend payments on the shorted stock to the entity from which the stock was borrowed. For shorted bonds, they must pay the lender the coupon or interest owed)

# %% [markdown]
# ### Commonly known advantages and disadvantages
# If the seller predicts the price moves correctly, they can make a positive return on investment, primarily if they use margin to initiate the trade. Using margin provides leverage, which means the trader does not need to put up much of their capital as an initial investment. If done carefully, short selling can be an inexpensive hedge, a counterbalance to other portfolio holdings.
#
# A trader who has shorted stock can lose much more than 100% of their original investment. The risk comes because there is no ceiling for a stock’s price. Also, while the stocks were held, the trader had to fund the margin account. When it comes time to close a position, a short seller might have trouble finding enough shares to buy, if many other traders are shorting the stock or the stock is thinly traded.
#
# Additionally, sellers can get caught in a short squeeze loop if the market, or a particular stock, starts to skyrocket. A short squeeze happens when the price of a stock begins to rise rapidly, forcing short-sellers who had bet against the stock to hastily buy the stock back to avoid incurring further losses. This is what happened with Volkswagen and Gamestop (more about them later). As the stock suddenly began to increase in price, buyers rushed in to trade the trend. Trend trading is a popular momentum day trading strategy. With a sudden influx of buyers looking to trade momentum and a lack of sellers, short sellers can only exit their position by executing buy orders at the market. By buying back their short positions, the short-sellers trigger a loop. The rising demand for the stock attracts more buyers, which sends the stock higher. Consequently, this forces even more shorts to cover their positions or buyback.

# %% [markdown]
# ## Real-World Examples
# ### Successes
# 1. **The Big Short (2008)**: Betting Against the Housing Market
#
# During the mid 2000s, a few investors recognized the instability in the U.S. housing market, particularly the risks associated with subprime mortgage-backed securities (MBS). They believed the housing bubble was going to burst and decided to use credit default swaps (CDS) to bet against these MBS-s. Notably, hedge fund managers like Michael Burry and Steve Eisman took significant short positions against these securities, anticipating a market collapse. Their foresight paid off when the housing bubble burst in 2008, leading to substantial profits for these investors,  while many financial institutions suffered significant losses.
#
# 2. **Wirecard (2020)**: Exposing Corporate Fraud
#
# Wirecard, a German payment processor, was once considered a fintech success story. However, persistent allegations from journalists and short sellers suggested financial irregularities. This "bank", as an idea, was original because it combined accounting fraud with money laundering on an epic scale, meaning it simultaneously hid revenue and embezzled cash while also inflating other sources of earnings. Interestingly enough, in spite of mounting evidence and the Financial Times' long campaign against them, known as 'The House of Wirecard,' which revealed increasingly damning evidence against them, Germany's regulators defended Wirecard robustly. After years of unfruitful attemps of taking the company down, on June 18, 2020, Wirecard announced that €1.9 billion was “missing” from two Philippine bank accounts. On June 25, Wirecard filed for insolvency. Short sellers who had bet against the company profited as its stock plummeted. This case shows that short sellers can act almost as watchdogs, uncovering corporate fraud that might go unnoticed by regulators.​ Their skepticism can prompt deeper investigations into companies' financial practices.
#
# ### Failures
# 3. **GameStop (2021)**: The Power of Retail Investors
#
# January 2021 saw one of the most notorious short squeezes in market history as Reddit's army of retail investors took on hedge funds to drive struggling retailer GameStop's stock price sky-high. In early 2021, GameStop, a struggling video game retailer, became the center of a trading frenzy. Beforehand hedge funds and other large, institutional players in the market had already begun to bet on the retailer’s demise, causing its stock price to dip below its per-share book value. When the COVID-19 pandemic shut down much of the retail economy in early 2020, it seemed GameStop’s fate was all but sealed. Over the next year, however, something unprecedented happened. A new generation of retail investors armed with pandemic stimulus money, unemployment checks, and lockdown free time, coordinating on platforms like Reddit's r/WallStreetBets, began buying shares in bulk, driving up the stock price. This surge led to a short squeeze, causing significant losses for hedge funds like Melvin Capital that had heavily shorted the stock. Melvin Capital required a $2.75 billion capital infusion to stabilize after the incident. A key takeaway from this tale is that collective action by retail investors can disrupt traditional market dynamics.
#
# 4. **Volkswagen (2008)**: A Historic Short Squeeze
#
# In 2008, Porsche revealed that it had acquired a significant stake in Volkswagen, leading to a scarcity of available shares for trading. This revelation triggered a massive short squeeze, causing Volkswagen's stock price to skyrocket and briefly making it the world's most valuable company by market capitalization. Short sellers faced substantial losses during this period. It has been reported that hedge funds that held short positions lost over $30 billion on the Volkswagen short squeeze. This incident showed investors that market dynamics, such as limited share availability, can lead to extreme volatility and understanding ownership structures is crucial for short sellers to assess potential risks.

# %% [markdown]
# ## Visualising indicators of a potential short squeeze

# %% [markdown]
# ### How to recognise a short squeeze
# Short squeezes can introduce a lot of volatility into stocks and send share prices sharply higher. These squeezes offer opportunities for trading, but they often require different strategies and more caution than traditional breakouts.
#
# As I have already discussed, a short squeeze occurs when the price of a stock rises sharply, forcing short sellers to buy shares to exit their positions. In buying shares to cover their short positions, short sellers end up pushing the stock price even higher. Bullish traders see this buying activity and jump in as well, adding further upward pressure to the share price. In this way, a relatively small bullish movement can trigger in a cascade of buying activity.
#
# Short squeezes typically happen only when the short interest in a stock is very high. It takes a lot of short sellers buying shares to push the price of a stock strongly upward. Short squeezes are usually short-lived and end when short sellers have fully exited their positions or stop buying shares to cut their losses.

# %% [markdown]
# ![short-squeeze](Short-Squeeze-Chart.jpg)

# %% [markdown]
# There are several ways that traders can recognize a short squeeze in action:
#
# **1. Checking for the short interest**
#
# A stock must have high short interest in order to experience a short squeeze. The best way to identify short squeeze candidates is to look at the number of shares short relative to a stock’s average daily trading volume. This is known as the days to cover ratio. Stocks with days to cover ratios of 5 or more may be more susceptible to short squeezes.
#
# **2. Checking the float**
#
# Stocks with low floats are also more susceptible to short squeezes. Low float stocks have fewer shares available for public trading, so short sellers will generally have a harder time covering their positions. Low float stocks are also typically more volatile than stocks with high float, which can help trigger a short squeeze.
#
# **3. Looking for volatility**
#
# Unusually high volatility could be a sign that a short squeeze is about to happen. Higher volatility may be due to short sellers starting to exit their positions in a hurry. High volatility could also induce a short squeeze if short sellers see that a stock has a very high days to cover ratio.
#
# **4. Looking for higher relative volume**
#
# Unusually high trading volume can be a sign that short sellers are buying shares to cover their short positions. As traders try to trade around the squeeze, trading volume will rise even higher. However, bear in mind that high trading volume is also associated with bullish breakouts.
#
# **5. Looking for catalysts**
#
# It’s important for traders to think about why a stock’s price is moving. If there’s a legitimate catalyst, such as a positive earnings report or industry-wide news, that may be the cause behind a sharp bullish price movement rather than a short squeeze.
#
# **6. Checking the trend**
#
# Short squeezes can happen during either uptrends or downtrends. However, a squeeze in a downtrend is less likely to occur because short sellers are less likely to experience margin calls (if they are holding unrealized profits in their short positions). Short sellers who hold unrealized profits may also be less incentivized to exit their positions if a stock is in the midst of a prolonged downtrend.
#
# **7. Examining open interest**
#
# Open interest generally refers to the total number of outstanding derivative contracts (like options or futures) that are currently active and have not been closed, exercised, or expired.
# In case of options, open interest is the number of contracts (calls or puts) currently open for a particular strike price and expiration date. Similarly when talking about futures, it's the number of outstanding contracts that are not yet settled.
# Unlike trading volume, which resets daily, open interest is cumulative, it increases when new positions are opened and decreases when they are closed! *How does open interest relate to short squeezes?*
#
# 1. High open interest in put options can indicate bearish sentiment or hedging, possibly due to heavy short positioning.
# 2. In a squeeze, rising prices can trigger margin calls or stop-losses, forcing short sellers to close positions. If there's high open interest, especially in options, it suggests a lot of leveraged bets—amplifying the move as positions unwind.
# 3. If many call options are bought and open interest is high, market makers may need to hedge by buying the underlying stock, driving up the price and potentially sparking a gamma squeeze, which can feed into a short squeeze.
#
# So it is worth looking out for rising short interest (especially in puts or OTM calls).

# %% [markdown]
# ### Tesla's days to cover ratio
# I opted for linear interpolation between the available bi-weekly data points in order to produce a smoother daily time series. This approach ensures consistency with the other plots in the project, which also represent continuous trends over time.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('tsla_short_interest.csv')
df['Settlement Date'] = pd.to_datetime(df['Settlement Date'])
df.set_index('Settlement Date', inplace=True)
df.sort_index(inplace=True)
all_days = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
df_daily = df.reindex(all_days)
df_daily.index.name = 'Date'

df_daily['Days to Cover'] = df_daily['Days to Cover'].interpolate(method='linear')

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Days to Cover'], 'o', label='Original Data Points', color='tab:blue')
plt.plot(df_daily.index, df_daily['Days to Cover'], '-', label='Interpolated (Daily)', color='tab:grey')

plt.xlabel('Date')
plt.ylabel('Days to Cover')
plt.title('Interpolated Days to Cover Ratio for Tesla (April 2024 - April 2025)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tesla's volatility

# %% [markdown]
# In this case, I chose to display the 30-day rolling volatility instead of the yearly one.
#
# **Why?**
#
# The 30-day rolling volatility is particularly beneficial for detecting short squeeze opportunities because it highlights recent and sudden increases in risk or price movement, which are key signs of a potential squeeze. It is effectively a gauge of future bets that investors and traders are making on the direction of the markets or individual securities. Some of its key properties include:
# - It is essentially the standard deviation of daily returns over a moving 30-day window.
# - It captures short-term price fluctuations and adapts over time, making it useful for tracking recent risk levels.
# - It's often used to monitor market turbulence and detect volatility spikes (e.g., before earnings or during crises).
#
# Conversely, Annualized volatility scales short-term volatility to a yearly basis, assuming daily returns follow a normal distribution and are i.i.d. (independent and identically distributed). This allows comparisons across assets and timeframes, and it is used in option pricing models (like Black-Scholes) and risk management.
#
# It is possible to calculate one from the other:
# $
# \sigma_{\text{annual}} = \sigma_{\text{30d}} \times \sqrt{252}
# $.

# %%
import yfinance as yf

tsla = yf.Ticker("TSLA")
data = tsla.history(start="2024-03-01", end="2025-04-15")

data['Daily_Return'] = data['Close'].pct_change()
data['Volatility'] = data['Daily_Return'].rolling(window=30).std()
data = data.dropna(subset=['Volatility'])

plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Volatility'], label='30-day Rolling Volatility', color='tab:blue')
plt.title('Tesla (TSLA) Volatility (April 2024 - April 2025)')
plt.xlabel('Date')
plt.ylabel('Volatility (30-day rolling std dev)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Tesla's relative trading volume

# %%
data['30d_Avg_Volume'] = data['Volume'].rolling(window=30).mean()

data['Relative_Volume'] = data['Volume'] / data['30d_Avg_Volume']

plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Relative_Volume'], label='Relative Volume', color='tab:blue')
plt.title('Tesla (TSLA) Relative Volume (April 2024 - April 2025)')
plt.xlabel('Date')
plt.ylabel('Relative Volume')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Tesla's price movement with volume

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(data.index, data['Close'], color='tab:blue', label='Close Price')
ax1.set_xlabel('Date')
ax1.set_ylabel('Closing Price (USD)', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.bar(data.index, data['Volume'], color='tab:gray', alpha=0.3, label='Volume')
ax2.set_ylabel('Volume', color='tab:gray')
ax2.tick_params(axis='y', labelcolor='tab:gray')

plt.title('Tesla (TSLA) Price Movement with Volume (April 2024 - March 2025)')
fig.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ## So, are Tesla stocks at a high risk of a short squeeze?
# Tesla has long been one of the most heavily shorted stocks in the US equity market, but is that so for a good reason?
#
# - The **days to cover ratio** tells us how many days it would take for all short sellers to buy back their shares if they all wanted to close their positions — assuming the average daily volume stays constant. A 1-day to cover ratio is considered to be relatively low. This would typically mean less risk of a short squeeze, suggesting high liquidity and not enough "pressure" to trigger a squeeze unless something else (like a catalyst) is involved.
#
# - Tesla is historically a **high-volatility** stock. In case of standard deviation of daily returns over a 30-day window, a value of 0.07 means the stock's daily returns fluctuated ~7% on average over the past month. This could indicate: quite large price swings, potentially elevated trading activity and market uncertainty or an upcoming catalyst.
#
# - ​Tesla's **relative volume** over the past year has shown notable fluctuations, reflecting periods of heightened trading activity. Relative volume compares a stock's current trading volume to its average volume over a specific period. A relative volume greater than 1 indicates that the stock is trading at a higher volume than usual, which can suggest increased investor interest or significant news events.​ Nowadays, this value has been decreasing, currently standing at roughly 0.75. This volume is below the 12-month average, suggesting a return to more typical trading activity following recent spikes.
#
# - Inspecting the **Price Movement vs Volume** graph, we can notice a recent decrease in trading activity after a considerable spike, while the closing prices have been on a downward trajectory since the end of 2024. A lower trading volume accompanied by a falling price is not a typical setup for a short squeeze. It usually needs rising price + increasing volume, especially when short interest is high. Decreasing volume suggests fewer buyers (or sellers), meaning any downward move is losing momentum, or market participants are waiting.
#
# **In conclusion, the data generally suggests low probability of an imminent short squeeze at the moment.**

# %% [markdown]
# ## Summary
# Short selling, while occasionally profitable, is generally a high-risk strategy with limited upside and potentially unlimited losses. Its effectiveness is often undermined by market volatility, timing challenges, and the threat of short squeezes, which can rapidly inflate prices against short positions. Structural limitations such as borrowing costs, margin requirements, and regulatory constraints further reduce its practicality for most investors. Further analysis of different stocks across the market shows that even when short interest exists, other indicators, such as low days-to-cover ratios or declining volatility, often signal a low likelihood of squeeze conditions. Overall, short selling is better viewed as a speculative tool rather than a reliable investment strategy.

# %% [markdown]
# ## My Sources

# %% [markdown]
# [How to Recognize a Short Squeeze](https://centerpointsecurities.com/how-to-recognize-a-short-squeeze/)
#
# [How the Wirecard scandal happened: Case study](https://www.transparently.ai/blog/how-the-wirecard-scandal-happened)
#
# [Remembering the Legendary Volkswagen Short Squeeze](https://www.warriortrading.com/volkswagen-short-squeeze/)
#
# ['The Big Short' Explained](https://www.investopedia.com/articles/investing/020115/big-short-explained.asp)
#
# [Wikipedia: The Big Short](https://en.wikipedia.org/wiki/The_Big_Short)
#
# [Short Selling: Your Step-by-Step Guide for Shorting Stocks](https://www.investopedia.com/terms/s/shortselling.asp)
#
# [An in-depth timeline of the GameStop short squeeze saga](https://www.thestreet.com/investing/stocks/a-timeline-of-the-gamestop-short-squeeze)
#
# [Nasdaq: Tesla, Inc. Common Stock (TSLA) Short Interest](https://www.nasdaq.com/market-activity/stocks/tsla/short-interest)
#
# [Investopedia: Volatility: Meaning in Finance and How It Works With Stocks](https://www.investopedia.com/terms/v/volatility.asp)
